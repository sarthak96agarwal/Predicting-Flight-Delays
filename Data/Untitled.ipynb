# %%
import pandas as pd
import numpy as np

# %%
terror = pd.read_csv("terror_data.csv")

# %%
terror.head()
# Out:
#    Unnamed: 0       eventid  iyear  imonth  iday  approxdate  extended  \
# 0       31921  201601020043   2016       1     2         NaN         1
# 1       32089  201601070024   2016       1     7         NaN         0
# 2       32394  201601150040   2016       1    15         NaN         0
# 3       33450  201602110023   2016       2    11         NaN         0
# 4       33764  201602180063   2016       2    18         NaN         0
#
#    resolution  country    country_txt   ...    \
# 0         NaN      217  United States   ...
# 1         NaN      217  United States   ...
# 2         NaN      217  United States   ...
# 3         NaN      217  United States   ...
# 4         NaN      217  United States   ...
#
#                                             addnotes  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# ...

# %%
df = pd.read_csv("merged.csv")

# %%
df[df['DEP_DELAY']>200].shape
# Out:
# (2642, 30)
